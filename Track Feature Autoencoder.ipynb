# %% [markdown]
# ## Track feature encoder using an Autoencoder
#
# We used simple feed forward netural network to create an autoencoder that will reduce the dimension of song feature list from more than 20 to 8

# %% [markdown]
# #### Importing necessary libraries for this notebook

# %%
import glob
import pandas as pd
import numpy as np
from tqdm import tqdm
import pickle

# %% [markdown]
# Loading the sampled track data that contains 29 features

# %%
track_pd = pd.read_csv("sampled_track_features_data.csv")
track_pd.head()
# Out:
#                                  track_id    duration  release_year  \
# 0  t_f9b9a072-8dae-4816-bfd6-d91fc75a5744  180.133331          1989
# 1  t_7f435320-5d3b-497d-9346-0c97429af2b9  539.760010          1980
# 2  t_949441c4-4920-4eed-b929-2d67d37b7bd9  114.133331          1983
# 3  t_63eae5ac-744a-46ee-b719-0db8e70d6f7f  164.906677          1983
# 4  t_3c2c29b5-c738-42c0-83e1-ee0e88ac834d  182.293335          1969
#
#    us_popularity_estimate  acousticness  beat_strength  bounciness  \
# 0               97.720734      0.002047       0.425469    0.486543
# 1               98.383158      0.075846       0.499848    0.494943
# 2               98.967866      0.002274       0.243778    0.229295
# 3               99.773741      0.005024       0.338580    0.331703
# 4               99.987810      0.198284       0.336354    0.353215
#
#    danceability  dyn_range_mean    energy  ...  time_signature   valence  \
# 0      0.654540        7.990334  0.625231  ...               4  0.691534
# 1      0.461215        7.512061  0.563252  ...               4  0.468440
# 2      0.290262        5.105952  0.958647  ...               4  0.293100
# 3      0.348846        6.060782  0.886674  ...               4  0.387131
# 4      0.395759        6.443376  0.338417  ...               4  0.377411
#
#    acoustic_vector_0  acoustic_vector_1  acoustic_vector_2  acoustic_vector_3  \
# 0           0.188888           0.306256          -0.325102          -0.532620
# 1           0.180359          -0.149974          -0.185145          -0.152791
# 2           0.101301           0.186855          -0.525412          -0.293849
# 3           0.132311           0.248023          -0.510729          -0.387413
# 4           0.083737          -0.306129           0.045954           0.078400
#
#   acoustic_vector_4  acoustic_vector_5  acoustic_vector_6  acoustic_vector_7
# 0          0.660405           0.149624          -0.354731           0.192537
# 1          0.560996           0.047161          -0.295635          -0.074902
# 2          0.596498           0.010453          -0.280584           0.418848
# 3          0.602931           0.033381          -0.312206           0.365894
# 4          0.666640          -0.032503          -0.299952          -0.584207
#
# [5 rows x 30 columns]

# %%
track_pd.columns
# Out:
# Index(['track_id', 'duration', 'release_year', 'us_popularity_estimate',
#        'acousticness', 'beat_strength', 'bounciness', 'danceability',
#        'dyn_range_mean', 'energy', 'flatness', 'instrumentalness', 'key',
#        'liveness', 'loudness', 'mechanism', 'mode', 'organism', 'speechiness',
#        'tempo', 'time_signature', 'valence', 'acoustic_vector_0',
#        'acoustic_vector_1', 'acoustic_vector_2', 'acoustic_vector_3',
#        'acoustic_vector_4', 'acoustic_vector_5', 'acoustic_vector_6',
#        'acoustic_vector_7'],
#       dtype='object')

# %% [markdown]
# Out of all the features, 20 features are selected that points to the song type/genre features.

# %%
relevant_features_list = ['track_id', 'acousticness', 'beat_strength', 'bounciness', 'danceability',
       'energy', 'flatness', 'instrumentalness',
       'liveness', 'mechanism', 'organism', 'speechiness',
       'valence', 'acoustic_vector_0', 'acoustic_vector_1', 
       'acoustic_vector_2', 'acoustic_vector_3',
       'acoustic_vector_4', 'acoustic_vector_5', 'acoustic_vector_6',
       'acoustic_vector_7']
print(len(relevant_features_list))
# Out:
# 21

# %%
relevant_features_track_pd = track_pd[relevant_features_list]
relevant_features_track_pd.head()
# Out:
#                                  track_id  acousticness  beat_strength  \
# 0  t_f9b9a072-8dae-4816-bfd6-d91fc75a5744      0.002047       0.425469
# 1  t_7f435320-5d3b-497d-9346-0c97429af2b9      0.075846       0.499848
# 2  t_949441c4-4920-4eed-b929-2d67d37b7bd9      0.002274       0.243778
# 3  t_63eae5ac-744a-46ee-b719-0db8e70d6f7f      0.005024       0.338580
# 4  t_3c2c29b5-c738-42c0-83e1-ee0e88ac834d      0.198284       0.336354
#
#    bounciness  danceability    energy  flatness  instrumentalness  liveness  \
# 0    0.486543      0.654540  0.625231  0.957158      3.155269e-03  0.261363
# 1    0.494943      0.461215  0.563252  0.916317      3.736224e-01  0.693975
# 2    0.229295      0.290262  0.958647  0.846197      5.658840e-02  0.259133
# 3    0.331703      0.348846  0.886674  0.904784      1.998796e-10  0.381728
# 4    0.353215      0.395759  0.338417  1.021726      2.620291e-06  0.138143
#
#    mechanism  ...  speechiness   valence  acoustic_vector_0  \
# 0   0.473837  ...     0.052713  0.691534           0.188888
# 1   0.187614  ...     0.065943  0.468440           0.180359
# 2   0.332016  ...     0.115356  0.293100           0.101301
# 3   0.185455  ...     0.137590  0.387131           0.132311
# 4   0.245665  ...     0.030352  0.377411           0.083737
#
#    acoustic_vector_1  acoustic_vector_2  acoustic_vector_3  acoustic_vector_4  \
# 0           0.306256          -0.325102          -0.532620           0.660405
# 1          -0.149974          -0.185145          -0.152791           0.560996
# 2           0.186855          -0.525412          -0.293849           0.596498
# 3           0.248023          -0.510729          -0.387413           0.602931
# 4          -0.306129           0.045954           0.078400           0.666640
#
#    acoustic_vector_5  acoustic_vector_6  acoustic_vector_7
# 0           0.149624          -0.354731           0.192537
# 1           0.047161          -0.295635          -0.074902
# 2           0.010453          -0.280584           0.418848
# 3           0.033381          -0.312206           0.365894
# 4          -0.032503          -0.299952          -0.584207
#
# [5 rows x 21 columns]

# %%
relevant_features_track_pd.shape
# Out:
# (275328, 21)

# %% [markdown]
# ## Feed forward Autoencoder

# %%
from keras.layers import Input, Dense
from keras.models import Model
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Creation of the autoencoder
#
# The feature values varies from -1 to +1, therefore tanh was chosen as the activation function.

# %%
input_features = Input(shape=(20,))
encoded = Dense(units=14, activation='tanh')(input_features)
encoded = Dense(units=8, activation='tanh')(encoded)
decoded = Dense(units=14, activation='tanh')(encoded)
decoded = Dense(units=20, activation='tanh')(decoded)

# %%
autoencoder = Model(input_features, decoded)

# %%
encoder = Model(input_features, encoded)

# %%
autoencoder.summary()
# Out:
# Model: "model_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         (None, 20)                0
# _________________________________________________________________
# dense_28 (Dense)             (None, 14)                294
# _________________________________________________________________
# dense_29 (Dense)             (None, 8)                 120
# _________________________________________________________________
# dense_30 (Dense)             (None, 14)                126
# _________________________________________________________________
# dense_31 (Dense)             (None, 20)                300
# =================================================================
# Total params: 840
# Trainable params: 840
# Non-trainable params: 0
# _________________________________________________________________

# %%
encoder.summary()
# Out:
# Model: "model_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         (None, 20)                0
# _________________________________________________________________
# dense_28 (Dense)             (None, 14)                294
# _________________________________________________________________
# dense_29 (Dense)             (None, 8)                 120
# =================================================================
# Total params: 414
# Trainable params: 414
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# %%
x_train = relevant_features_track_pd.loc[:, relevant_features_track_pd.columns != 'track_id']
x_train.head()
# Out:
#    acousticness  beat_strength  bounciness  danceability    energy  flatness  \
# 0      0.002047       0.425469    0.486543      0.654540  0.625231  0.957158
# 1      0.075846       0.499848    0.494943      0.461215  0.563252  0.916317
# 2      0.002274       0.243778    0.229295      0.290262  0.958647  0.846197
# 3      0.005024       0.338580    0.331703      0.348846  0.886674  0.904784
# 4      0.198284       0.336354    0.353215      0.395759  0.338417  1.021726
#
#    instrumentalness  liveness  mechanism  organism  speechiness   valence  \
# 0      3.155269e-03  0.261363   0.473837  0.372056     0.052713  0.691534
# 1      3.736224e-01  0.693975   0.187614  0.576942     0.065943  0.468440
# 2      5.658840e-02  0.259133   0.332016  0.472339     0.115356  0.293100
# 3      1.998796e-10  0.381728   0.185455  0.575982     0.137590  0.387131
# 4      2.620291e-06  0.138143   0.245665  0.551515     0.030352  0.377411
#
#    acoustic_vector_0  acoustic_vector_1  acoustic_vector_2  acoustic_vector_3  \
# 0           0.188888           0.306256          -0.325102          -0.532620
# 1           0.180359          -0.149974          -0.185145          -0.152791
# 2           0.101301           0.186855          -0.525412          -0.293849
# 3           0.132311           0.248023          -0.510729          -0.387413
# 4           0.083737          -0.306129           0.045954           0.078400
#
#    acoustic_vector_4  acoustic_vector_5  acoustic_vector_6  acoustic_vector_7
# 0           0.660405           0.149624          -0.354731           0.192537
# 1           0.560996           0.047161          -0.295635          -0.074902
# 2           0.596498           0.010453          -0.280584           0.418848
# 3           0.602931           0.033381          -0.312206           0.365894
# 4           0.666640          -0.032503          -0.299952          -0.584207

# %%
autoencoder.fit(x_train, x_train, epochs=50, batch_size=128, shuffle=False)
# Out:
# Epoch 1/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0246
# Epoch 2/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0076
# Epoch 3/50
# 275328/275328 [==============================] - 2s 6us/step - loss: 0.0070
# Epoch 4/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0065
# Epoch 5/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0059
# Epoch 6/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0055
# Epoch 7/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0053
# Epoch 8/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0049
# Epoch 9/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0048
# Epoch 10/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0047
# Epoch 11/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0046
# Epoch 12/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0046
# Epoch 13/50
# 275328/275328 [==============================] - 2s 8us/step - loss: 0.0045
# Epoch 14/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0045
# Epoch 15/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0045
# Epoch 16/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0044
# Epoch 17/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0044
# Epoch 18/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0044
# Epoch 19/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0043
# Epoch 20/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0043
# Epoch 21/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0043
# Epoch 22/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0043
# Epoch 23/50
# 275328/275328 [==============================] - 2s 8us/step - loss: 0.0042
# Epoch 24/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0042
# Epoch 25/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0042
# Epoch 26/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0042
# Epoch 27/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0042
# Epoch 28/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0041
# Epoch 29/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0041
# Epoch 30/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0041
# Epoch 31/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0041
# Epoch 32/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0041
# Epoch 33/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0041
# Epoch 34/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0040
# Epoch 35/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0040
# Epoch 36/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0040
# Epoch 37/50
# 275328/275328 [==============================] - 2s 8us/step - loss: 0.0040
# Epoch 38/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0040
# Epoch 39/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0040
# Epoch 40/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0040
# Epoch 41/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0040
# Epoch 42/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0039
# Epoch 43/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0039
# Epoch 44/50
# 275328/275328 [==============================] - 2s 8us/step - loss: 0.0039
# Epoch 45/50
# 275328/275328 [==============================] - 2s 8us/step - loss: 0.0039
# Epoch 46/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0039
# Epoch 47/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0039
# Epoch 48/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0039
# Epoch 49/50
# 275328/275328 [==============================] - 2s 8us/step - loss: 0.0039
# Epoch 50/50
# 275328/275328 [==============================] - 2s 7us/step - loss: 0.0039

# %% [markdown]
# The prediction from the encoder is the latent representation of each song.

# %%
latent_track_features = encoder.predict(x_train)

# %%
latent_track_features.shape
# Out:
# (275328, 8)

# %%
latent_track_features_dict = dict()
for ind in tqdm(track_pd.index):
    track_id = track_pd['track_id'][ind]
    latent_features = latent_track_features[ind]
    latent_track_features_dict[track_id] = latent_features
# Out:
# 100%|██████████| 275328/275328 [00:02<00:00, 101650.91it/s]

# %%
latent_track_features_df = pd.DataFrame.from_dict(latent_track_features_dict, orient='index')
latent_track_features_df.reset_index(inplace = True)
latent_track_features_df.rename(columns={'index':'track_id'}, inplace=True)
latent_track_features_df.head()
# Out:
#                                  track_id         0         1         2  \
# 0  t_f9b9a072-8dae-4816-bfd6-d91fc75a5744  0.085536  0.023943  0.125375
# 1  t_7f435320-5d3b-497d-9346-0c97429af2b9  0.152102 -0.118725 -0.168167
# 2  t_949441c4-4920-4eed-b929-2d67d37b7bd9  0.056647 -0.077121  0.052887
# 3  t_63eae5ac-744a-46ee-b719-0db8e70d6f7f  0.120041 -0.071038 -0.012514
# 4  t_3c2c29b5-c738-42c0-83e1-ee0e88ac834d  0.075071  0.094992  0.372702
#
#           3         4         5         6         7
# 0 -0.145933  0.449010 -0.106019 -0.190885  0.282416
# 1  0.291125  0.540807  0.042686 -0.288468  0.130090
# 2 -0.076303  0.644329 -0.148826 -0.292301  0.208705
# 3 -0.061835  0.621581 -0.082328 -0.210929  0.185848
# 4  0.001345  0.534761 -0.017185 -0.420036  0.035725

# %%
latent_track_features_df.shape
# Out:
# (275328, 9)

# %%
latent_track_features_df.to_csv('latent_track_features.csv', index=False)

# %%
pickle.dump(encoder, open('pickle/track_encoder.sav', 'wb'))

# %%
pickle.dump(autoencoder, open('pickle/track_autoencoder.sav', 'wb'))
