# %% [markdown]
# ### This file samples data from the entire dataset and pull 100 thousands sessions.

# %%
import glob
import pandas as pd
import numpy as np

# %%
data_file_list = glob.glob("data/*")
session_data_df = pd.read_csv(data_file_list[0])
session_data_df.head()
# Out:
#                                 session_id  session_position  session_length  \
# 0  54_00003a1a-0ade-4cb7-828d-c2ab43cfa99a                 1              18
# 1  54_00003a1a-0ade-4cb7-828d-c2ab43cfa99a                 2              18
# 2  54_00003a1a-0ade-4cb7-828d-c2ab43cfa99a                 3              18
# 3  54_00003a1a-0ade-4cb7-828d-c2ab43cfa99a                 4              18
# 4  54_00003a1a-0ade-4cb7-828d-c2ab43cfa99a                 5              18
#
#                            track_id_clean  skip_1  skip_2  skip_3  \
# 0  t_5c8354bd-87a0-46ac-94d3-811e3c423148   False   False    True
# 1  t_763e4d1d-e894-4a2b-8d37-195e0ea532aa   False   False    True
# 2  t_504aa03c-1e9a-473d-b8e3-b647be2f7207   False    True    True
# 3  t_ac02ec7b-8e9e-46c4-9599-d959ca0bb622   False    True    True
# 4  t_3ad9ca25-7f39-4b9d-b924-63abaddc2783    True    True    True
#
#    not_skipped  context_switch  no_pause_before_play  ...  \
# 0        False               0                     0  ...
# 1        False               0                     1  ...
# 2        False               0                     1  ...
# 3        False               0                     1  ...
# 4        False               0                     1  ...
#
#    long_pause_before_play  hist_user_behavior_n_seekfwd  \
# 0                       0                             0
# 1                       0                             0
# 2                       0                             1
# 3                       0                             1
# 4                       0                             0
#
#    hist_user_behavior_n_seekback  hist_user_behavior_is_shuffle  hour_of_day  \
# 0                              0                          False           15
# 1                              0                          False           15
# 2                              0                          False           15
# 3                              0                          False           15
# 4                              0                          False           15
#
#          date premium  context_type hist_user_behavior_reason_start  \
# 0  2018-09-07    True         radio                          fwdbtn
# 1  2018-09-07    True         radio                          fwdbtn
# 2  2018-09-07    True         radio                          fwdbtn
# 3  2018-09-07    True         radio                          fwdbtn
# 4  2018-09-07    True         radio                          fwdbtn
#
#   hist_user_behavior_reason_end
# 0                        fwdbtn
# 1                        fwdbtn
# 2                        fwdbtn
# 3                        fwdbtn
# 4                        fwdbtn
#
# [5 rows x 21 columns]

# %%
def sample_data(filename, sample_size):
    df = pd.read_csv(filename)
    twenty_session_length_session_ids = df[df['session_length'] == 20].session_id.unique()
    random_sampled_session_ids = np.random.choice(twenty_session_length_session_ids, sample_size, False)
    sampled_df = df[df.session_id.isin(random_sampled_session_ids)]
    return sampled_df

# %%
from tqdm import tqdm
sampled_batch_df = pd.DataFrame(columns = session_data_df.columns)
sample_size = int(10000/len(data_file_list))
for file_name in tqdm(data_file_list):
    sampled_batch_df = sampled_batch_df.append(sample_data(file_name, sample_size))
sampled_batch_df.head()
# Out:
# 100%|██████████| 66/66 [12:41<00:00, 11.81s/it]
#                                   session_id session_position session_length  \
# 777  54_0011d5be-cf85-452a-9ff8-0cc6be481093                1             20
# 778  54_0011d5be-cf85-452a-9ff8-0cc6be481093                2             20
# 779  54_0011d5be-cf85-452a-9ff8-0cc6be481093                3             20
# 780  54_0011d5be-cf85-452a-9ff8-0cc6be481093                4             20
# 781  54_0011d5be-cf85-452a-9ff8-0cc6be481093                5             20
#
#                              track_id_clean skip_1 skip_2 skip_3 not_skipped  \
# 777  t_d6c18adb-c4d3-453e-be5d-c6f991d9a992  False   True   True       False
# 778  t_a75a857b-78a7-4366-b08b-5c01d152747e  False  False   True       False
# 779  t_4a16b7e1-f57e-4eda-be9b-818c23b26261  False  False   True       False
# 780  t_55dffb67-4b17-4442-bb65-2c110c6ead36  False  False  False        True
# 781  t_56da4464-c1dd-497f-9853-6cf7e8b35705  False   True   True       False
#
#     context_switch no_pause_before_play  ... long_pause_before_play  \
# 777              0                    0  ...                      0
# 778              0                    1  ...                      0
# 779              0                    1  ...                      0
# 780              0                    1  ...                      0
# 781              0                    0  ...                      1
#
#     hist_user_behavior_n_seekfwd hist_user_behavior_n_seekback  \
# 777                            0                             0
# 778                            0                             0
# 779                            0                             0
# 780                            0                             0
# 781                            0                             0
#
#     hist_user_behavior_is_shuffle hour_of_day        date premium  \
# 777                         False           8  2018-09-07    True
# 778                         False           8  2018-09-07    True
# 779                         False           8  2018-09-07    True
# 780                         False           8  2018-09-07    True
# 781                         False           8  2018-09-07    True
#
#     context_type hist_user_behavior_reason_start hist_user_behavior_reason_end
# 777        radio                          fwdbtn                        fwdbtn
# 778        radio                          fwdbtn                        fwdbtn
# 779        radio                          fwdbtn                        fwdbtn
# 780        radio                          fwdbtn                     trackdone
# 781        radio                       trackdone                        fwdbtn
#
# [5 rows x 21 columns]

# %%
sampled_batch_df.shape
# Out:
# (199320, 21)

# %%
sampled_batch_df.to_csv('sampled_data_8.csv', index=False)
